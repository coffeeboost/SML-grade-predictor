1,2,services,2,services,T,4,0,no,U,18,0,5,LE3,no,4,5,father,3,yes,298,yes,yes,no,course,yes,MS,no,F,3,P,2
1,1,services,1,at_home,T,2,2,no,U,18,1,4,GT3,no,4,2,mother,2,no,299,no,yes,no,course,no,MS,no,F,2,P,3
3,2,other,4,teacher,T,1,0,no,U,17,0,4,GT3,no,2,3,father,5,yes,300,yes,yes,no,course,yes,MS,no,F,4,P,2
1,1,other,2,services,A,2,5,yes,R,17,0,5,LE3,no,3,3,mother,2,yes,301,yes,yes,no,reputation,yes,MS,no,F,2,P,2
1,4,services,4,teacher,T,2,2,yes,R,17,0,4,GT3,yes,3,3,father,5,yes,302,yes,yes,yes,other,no,MS,no,F,2,P,2
1,4,at_home,4,at_home,T,1,4,yes,U,17,0,2,LE3,yes,3,4,mother,1,yes,303,yes,yes,no,course,yes,MS,no,F,2,P,1
2,3,other,1,at_home,T,4,0,no,R,18,0,3,GT3,yes,3,4,mother,3,yes,304,no,yes,yes,course,no,MS,no,M,2,P,2
1,3,services,2,at_home,T,2,0,no,U,18,0,5,GT3,yes,2,3,father,4,yes,305,yes,yes,no,course,yes,MS,no,F,1,P,2
2,2,services,1,at_home,T,3,3,yes,R,18,0,4,LE3,yes,3,3,father,3,no,306,yes,yes,no,other,yes,MS,no,M,1,P,3
1,2,other,1,other,T,3,4,yes,R,17,0,3,GT3,no,5,5,mother,1,yes,307,yes,yes,no,course,no,MS,no,F,1,P,1
1,4,other,4,other,T,1,0,no,R,18,0,5,LE3,no,4,4,mother,1,yes,308,yes,yes,no,reputation,no,MS,no,F,3,P,2
1,4,teacher,4,teacher,T,4,4,yes,U,18,0,3,GT3,no,2,4,father,2,yes,309,yes,no,no,home,no,MS,no,M,2,P,1
1,1,other,2,other,T,3,0,yes,R,18,0,4,GT3,no,4,3,mother,5,yes,310,yes,no,no,other,yes,MS,no,M,1,P,2
1,3,services,2,other,T,1,4,yes,U,17,0,4,GT3,no,4,3,father,3,yes,311,yes,yes,no,home,no,MS,no,M,2,P,2
3,2,other,3,services,T,4,4,no,R,18,0,4,LE3,no,4,1,mother,5,yes,312,yes,no,no,course,no,MS,no,M,1,P,3
"""

# %% [markdown]
# # The Code

# %%
# library convert strings to IO Object for Pandas
from io import StringIO
import pandas as pd
import numpy as np
import sklearn as skl
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error
from math import sqrt
from google.colab import files
from sklearn.utils import shuffle
import seaborn as sns
from itertools import combinations
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
import xgboost as xgb

trainset = pd.read_csv(StringIO(traincsv))
testset = pd.read_csv(StringIO(testcsv))

# %%
trainset
# Out:
#     school sex  age address famsize  ... health  absences  subject grade   id
# 0       MS   M   16       R     LE3  ...      5         0        P     9    0
# 1       GP   F   18       U     LE3  ...      3        18        P    10    1
# 2       GP   M   16       R     GT3  ...      4         6        P    11    2
# 3       GP   F   16       U     GT3  ...      2         8        M    10    3
# 4       GP   F   20       R     GT3  ...      2         8        P    12    4
# ..     ...  ..  ...     ...     ...  ...    ...       ...      ...   ...  ...
# 726     GP   M   18       U     GT3  ...      3         2        P    11  726
# 727     GP   M   15       U     GT3  ...      3         0        M    16  727
# 728     MS   F   18       R     GT3  ...      4         2        M    10  728
# 729     MS   F   18       R     LE3  ...      1         0        M    19  729
# 730     GP   M   17       U     GT3  ...      3         0        P    10  730
#
# [731 rows x 33 columns]

# %%
testset
# Out:
#      Dalc  Fedu      Fjob  Medu  ... sex studytime  subject  traveltime
# 0       1     4     other     3  ...   M         2        M           1
# 1       1     3     other     4  ...   M         1        M           1
# 2       1     4    health     2  ...   F         3        M           1
# 3       1     3     other     3  ...   M         2        M           1
# 4       1     3     other     2  ...   F         1        M           2
# ..    ...   ...       ...   ...  ...  ..       ...      ...         ...
# 308     1     4     other     4  ...   F         3        P           2
# 309     1     4   teacher     4  ...   M         2        P           1
# 310     1     1     other     2  ...   M         1        P           2
# 311     1     3  services     2  ...   M         2        P           2
# 312     3     2     other     3  ...   M         1        P           3
#
# [313 rows x 32 columns]

# %% [markdown]
# Note that test set is not in the same order as the training set

# %% [markdown]
# ### Reorganising Test Set Dataframe

# %%
trainset = trainset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject', 'grade']]
testset = testset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject']]

# %% [markdown]
# # Exploring Training Variables

# %%
#make trainset that only has int
#columns that use numbers: id,age,Medu,Fedu,traveltime,studytime,failures,famrel,freetime,goout,Dalc,Walc,health,absences,grade
#randomise rows for more even results
trainset = trainset[[
                    'age',
                    'Medu',
                    'Fedu',
                    'traveltime',
                    'studytime',
                    'failures',
                    'famrel',
                    'freetime',
                    'goout',
                    'Dalc',
                    'Walc',
                    'health',
                    'absences',
                    'grade']]
trainset = shuffle(trainset)
trainset
# trainset2 = trainset.drop(['grade','id'],axis=1)
# trainset
# Out:
#      age  Medu  Fedu  traveltime  ...  Walc  health  absences  grade
# 711   16     1     2           1  ...     1       1         4      9
# 56    15     4     1           1  ...     2       2         7      8
# 137   18     4     4           1  ...     2       3         3     11
# 536   18     1     2           2  ...     2       4         0     14
# 520   16     3     1           1  ...     2       5         2     14
# ..   ...   ...   ...         ...  ...   ...     ...       ...    ...
# 246   18     3     4           1  ...     3       5        11     15
# 72    16     4     4           1  ...     2       2         4     14
# 606   18     2     1           1  ...     1       5        12     13
# 637   16     1     2           1  ...     2       3         2     11
# 647   15     1     2           1  ...     1       5         6     13
#
# [731 rows x 14 columns]

# %%
#exploring abnormal amounts of zero grade
#filter df for grade
trainset2 = trainset[trainset['grade']==0]
trainset2
# Out:
#      age  Medu  Fedu  traveltime  ...  Walc  health  absences  grade
# 249   15     4     3           2  ...     1       3         0      0
# 478   17     2     1           1  ...     2       5         0      0
# 8     19     1     1           2  ...     3       5         0      0
# 599   19     4     4           2  ...     3       2         0      0
# 186   18     4     2           1  ...     1       5         0      0
# 141   18     4     4           1  ...     2       2         0      0
# 416   16     4     3           1  ...     1       3         0      0
# 70    16     1     3           1  ...     1       3         0      0
# 156   19     1     1           2  ...     3       2         0      0
# 442   18     2     2           2  ...     1       3         0      0
# 328   18     4     2           2  ...     3       3         0      0
# 106   16     4     4           1  ...     1       5         0      0
# 129   19     1     1           2  ...     4       1         0      0
# ...

# %%
# trainset2.hist(color='g')
# plt.tight_layout(pad=0.7, w_pad=0.7, h_pad=1.6)

# %%
trainset3 = trainset[trainset['grade']!=0]
trainset3
# Out:
#      age  Medu  Fedu  traveltime  ...  Walc  health  absences  grade
# 711   16     1     2           1  ...     1       1         4      9
# 56    15     4     1           1  ...     2       2         7      8
# 137   18     4     4           1  ...     2       3         3     11
# 536   18     1     2           2  ...     2       4         0     14
# 520   16     3     1           1  ...     2       5         2     14
# ..   ...   ...   ...         ...  ...   ...     ...       ...    ...
# 246   18     3     4           1  ...     3       5        11     15
# 72    16     4     4           1  ...     2       2         4     14
# 606   18     2     1           1  ...     1       5        12     13
# 637   16     1     2           1  ...     2       3         2     11
# 647   15     1     2           1  ...     1       5         6     13
#
# [690 rows x 14 columns]

# %%
#compare grade is 0 to not 0
#observe that shape of histograms are very similar
#hence the conclusion is that grade = 0 are bad data
f, axs = plt.subplots(4,4,figsize=(20,20))
ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12,ax13,ax14,_,_ = axs.flatten()
width = 0.3
f.patch.set_facecolor('w')

column='age'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax1.bar(a_bins[:-1], a_heights/trainset2.size, width=width, facecolor='cornflowerblue',label='grade is 0')
ax1.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, facecolor='seagreen',label='grade is not 0')
ax1.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax1.set_title(column)

column='Medu'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax2.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax2.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax2.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax2.set_title(column)


column='Fedu'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax3.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax3.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax3.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax3.set_title(column)



column='traveltime'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax4.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax4.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax4.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax4.set_title(column)




column='studytime'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax5.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax5.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax5.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax5.set_title(column)



column='failures'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax6.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax6.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax6.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax6.set_title(column)




column='famrel'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])
width = 0.3

ax7.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax7.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax7.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax7.set_title(column)




column='freetime'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax8.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax8.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax8.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax8.set_title(column)




column='goout'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax9.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax9.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax9.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax9.set_title(column)



column='Dalc'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax10.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax10.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax10.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax10.set_title(column)





column='Walc'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax11.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax11.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax11.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax11.set_title(column)




column='health'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])

ax12.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax12.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax12.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax12.set_title(column)


column='absences'
a_heights, a_bins = np.histogram(trainset2[column])
b_heights, b_bins = np.histogram(trainset3[column])
c_heights, c_bins = np.histogram(testset[column])
width=5
ax13.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')
ax13.bar(b_bins[:-1]+width, b_heights/trainset3.size, width=width, color='seagreen',label='grade is not 0')
ax13.bar(c_bins[:-1], c_heights/testset.size, width=width, facecolor='r',label='testset')

ax13.set_title(column)


column='grade'
a_heights, a_bins = np.histogram(trainset2[column])
ax14.bar(a_bins[:-1], a_heights/trainset2.size, width=width, color='cornflowerblue',label='grade is 0')

ax14.set_title(column)

ax1.legend()
ax2.legend()
ax3.legend()
ax4.legend()
ax5.legend()
ax6.legend()
ax7.legend()
ax8.legend()
ax9.legend()
ax10.legend()
ax11.legend()
ax12.legend()
ax13.legend()
ax14.legend()



plt.show()

# %%
#repeat experiment on testset (note:it has been included in the plot above)
f, axs = plt.subplots(4,4,figsize=(20,20))
ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9,ax10,ax11,ax12,ax13,ax14,_,_ = axs.flatten()
width = 0.3
f.patch.set_facecolor('w')

column='age'
a_heights, a_bins = np.histogram(testset[column])
ax1.bar(a_bins[:-1], a_heights/testset.size, width=width, facecolor='r',label='testset')
ax1.set_title(column)
ax1.legend()


column='Medu'
a_heights, a_bins = np.histogram(testset[column])
ax2.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax2.set_title(column)


column='Fedu'
a_heights, a_bins = np.histogram(testset[column])
ax3.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax3.set_title(column)


column='traveltime'
a_heights, a_bins = np.histogram(testset[column])
ax4.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax4.set_title(column)


column='studytime'
a_heights, a_bins = np.histogram(testset[column])
ax5.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax5.set_title(column)
ax5.legend()

column='failures'
a_heights, a_bins = np.histogram(testset[column])
ax6.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax6.set_title(column)

column='famrel'
a_heights, a_bins = np.histogram(testset[column])
ax7.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax7.set_title(column)


column='freetime'
a_heights, a_bins = np.histogram(testset[column])
ax8.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax8.set_title(column)

column='goout'
a_heights, a_bins = np.histogram(testset[column])
ax9.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax9.set_title(column)
ax9.legend()


column='Dalc'
a_heights, a_bins = np.histogram(testset[column])

ax10.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax10.set_title(column)


column='Walc'
a_heights, a_bins = np.histogram(testset[column])
ax11.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax11.set_title(column)


column='health'
a_heights, a_bins = np.histogram(testset[column])
ax12.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax12.set_title(column)


column='absences'
a_heights, a_bins = np.histogram(testset[column])
width=5
ax13.bar(a_bins[:-1], a_heights/testset.size, width=width, color='r',label='grade is 0')
ax13.set_title(column)
ax13.legend()

plt.show()

# %%
trainset3
# Out:
#      age  Medu  Fedu  traveltime  ...  Walc  health  absences  grade
# 711   16     1     2           1  ...     1       1         4      9
# 56    15     4     1           1  ...     2       2         7      8
# 137   18     4     4           1  ...     2       3         3     11
# 536   18     1     2           2  ...     2       4         0     14
# 520   16     3     1           1  ...     2       5         2     14
# ..   ...   ...   ...         ...  ...   ...     ...       ...    ...
# 246   18     3     4           1  ...     3       5        11     15
# 72    16     4     4           1  ...     2       2         4     14
# 606   18     2     1           1  ...     1       5        12     13
# 637   16     1     2           1  ...     2       3         2     11
# 647   15     1     2           1  ...     1       5         6     13
#
# [690 rows x 14 columns]

# %%
#predict grades using random forest resgressor with cleaner data
#while removing grade = 0

X_train = trainset3[['age',	'Medu',	'Fedu',	'traveltime',	'studytime'	,'failures',	'famrel',	'freetime',	'goout',	'Dalc',	'Walc',	'health',	'absences']]
y_train = trainset3['grade']
X_predict  = testset[['age',	'Medu',	'Fedu',	'traveltime',	'studytime'	,'failures',	'famrel',	'freetime',	'goout',	'Dalc',	'Walc',	'health',	'absences']]

regr = RandomForestRegressor(random_state=0)
regr.fit(X_train,y_train)
y_predicted = pd.Series(regr.predict(X_predict),name="grade").round()

# result = pd.concat([testset["id"],pd.DataFrame(y_predicted)],axis=1)
# result.to_csv("data.csv",index=False)
# files.download("data.csv")

# %% [markdown]
# # Exploring pairs of parameters

# %%
trainset = pd.read_csv(StringIO(traincsv))
testset = pd.read_csv(StringIO(testcsv))
trainset = trainset[[
                    'age',
                    'Medu',
                    'Fedu',
                    'traveltime',
                    'studytime',
                    'failures',
                    'famrel',
                    'freetime',
                    'goout',
                    'Dalc',
                    'Walc',
                    'health',
                    'absences',
                    'grade']]
testset = testset[[
                    'age',
                    'Medu',
                    'Fedu',
                    'traveltime',
                    'studytime',
                    'failures',
                    'famrel',
                    'freetime',
                    'goout',
                    'Dalc',
                    'Walc',
                    'health',
                    'absences']]

# %%
#new plan: for every pair, find the best rmse score
#conclusion: no real relationship between pairs

#intialise dataframe
df123 = pd.DataFrame(columns=['attribute1','attribute2','rmse'])
trainset = trainset[trainset['grade']!=0]
trainset2 = shuffle(trainset.drop(columns='grade'))


def training(X_train,y_train,X_predict,y_actual):
  regr = RandomForestRegressor(random_state=0)
  regr.fit(X_train,y_train)
  y_predicted = regr.predict(X_predict)
  rms = sqrt(mean_squared_error(y_actual, y_predicted))
  return rms

# calculate every rmse score
for attribute in trainset2.columns:
  for second_attribute in trainset2.columns:
    X_train = trainset2[[attribute,second_attribute]].iloc[0:150].to_numpy()
    X_predict = trainset2[[attribute,second_attribute]].iloc[150:313].to_numpy()
    y_train = trainset['grade'].iloc[0:150]
    y_actual = trainset['grade'].iloc[150:313].to_numpy()

    rmse = training(X_train,y_train,X_predict,y_actual)
    
    # save the result in my dataframe
    df123 = df123.append(pd.DataFrame([[attribute,second_attribute,rmse]],columns = ['attribute1','attribute2','rmse']))

#plotting rmse results
sns.set()
result = df123.pivot(index='attribute1', columns='attribute2',values='rmse')
g = sns.heatmap(result,vmin=2.5,vmax=3.5)

# %%
## make a sample submission
# regr = RandomForestRegressor(max_depth=2, random_state=0)
# X_train = trainset[["studytime","freetime","health"]].to_numpy()
# y_train = trainset["grade"].to_numpy()
# X_predict = trainset[["studytime","freetime","health"]].to_numpy()

# regr.fit(X_train,y_train)
# y_predicted = pd.Series(regr.predict(X_predict),name="grade")
# result = pd.concat([trainset["id"],pd.DataFrame(y_predicted)],axis=1)
# result.to_csv("data.csv",index=False)

# files.download("data.csv")

# %% [markdown]
# # Forecasting with random forest classifier

# %%
#setting up dataframe for model
#reorganise columns,remove grade 0, X,y
trainset = pd.read_csv(StringIO(traincsv))
testset = pd.read_csv(StringIO(testcsv))
trainset = trainset[trainset.grade!=0]
trainset = trainset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject', 'grade']]
testset = testset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject']]
y = trainset['grade']
X = trainset.drop('grade',axis='columns').set_index('id')
testset.set_index('id',inplace=True)

# %%
encode_dict ={
    'other':0,
    'teacher':1,
    'health':2,
    'services':3,
    'at_home':4,
    'home':1,
    'reputation':2,
    'course':3,
    'mother':1,
    'father':2,
    'MS':1,
    'GP':2,
    'M':1,
    'F':2,
    'R':1,
    'U':2,
    'LE3':1,
    'GT3':2,
    'yes':1,
    'no':2,
    'P':1,
    'M':2,
    'T':1,
    'A':2
}
X.replace(encode_dict,inplace=True)
testset.replace(encode_dict,inplace=True)
X
# Out:
#      school  sex  age  address  famsize  ...  Dalc  Walc  health  absences  subject
# id                                       ...
# 0         1    2   16        1        1  ...     2     4       5         0        1
# 1         2    2   18        2        1  ...     1     1       3        18        1
# 2         2    2   16        1        2  ...     1     1       4         6        1
# 3         2    2   16        2        2  ...     1     1       2         8        2
# 4         2    2   20        1        2  ...     1     2       2         8        1
# ..      ...  ...  ...      ...      ...  ...   ...   ...     ...       ...      ...
# 726       2    2   18        2        2  ...     1     1       3         2        1
# 727       2    2   15        2        2  ...     1     1       3         0        2
# 728       1    2   18        1        2  ...     1     2       4         2        2
# 729       1    2   18        1        1  ...     1     1       1         0        2
# ...

# %%
testset
# Out:
#      school  sex  age  address  famsize  ...  Dalc  Walc  health  absences  subject
# id                                       ...
# 0         2    2   15        2        2  ...     1     1       5         0        2
# 1         2    2   16        2        1  ...     1     3       5         4        2
# 2         2    2   15        1        2  ...     1     1       5         2        2
# 3         2    2   15        2        1  ...     1     1       2         0        2
# 4         2    2   15        2        2  ...     1     1       5         0        2
# ..      ...  ...  ...      ...      ...  ...   ...   ...     ...       ...      ...
# 308       1    2   18        1        1  ...     1     1       1         0        1
# 309       1    2   18        2        2  ...     1     4       2         4        1
# 310       1    2   18        1        2  ...     1     3       5         0        1
# 311       1    2   17        2        2  ...     1     1       3         4        1
# ...

# %%
#optimise learning model
X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.4)
d = []
for n in range(1,100):
  clf = RandomForestClassifier(max_depth=n, random_state=0)
  clf.fit(X_train,y_train)
  result = clf.predict(X_test)
  rms = sqrt(mean_squared_error(y_test, result))
  d.append((n,rms))

# %%
#optimising max_depth
plt.scatter(*zip(*d))
plt.xlim(0,20)
plt.xticks(np.arange(0,20, 1.0))
plt.xlabel('n')
plt.ylabel('rms score')
plt.title('optimising max_depth')
plt.show()

# %%
clf = RandomForestClassifier(max_depth=7, random_state=0)
clf.fit(X,y)
predicted_grade = pd.DataFrame(clf.predict(testset),columns=['grade'])
id = testset.reset_index()['id']
submission = pd.concat([id,predicted_grade],axis=1)
submission.to_csv("submission.csv",index=False)
files.download("submission.csv")

# %%
'''
>>> from sklearn.ensemble import RandomForestClassifier
>>> from sklearn.datasets import make_classification
>>> X, y = make_classification(n_samples=1000, n_features=4,
...                            n_informative=2, n_redundant=0,
...                            random_state=0, shuffle=False)
>>> clf = RandomForestClassifier(max_depth=2, random_state=0)
>>> clf.fit(X, y)
RandomForestClassifier(...)
>>> print(clf.predict([[0, 0, 0, 0]]))
[1]

'''
# Out:
# '\nfrom sklearn.ensemble import RandomForestClassifier\nfrom sklearn.datasets import make_classification\nX, y = make_classification(n_samples=1000, n_features=4,\n                           n_informative=2, n_redundant=0,\n                           random_state=0, shuffle=False)\nclf = RandomForestClassifier(max_depth=2, random_state=0)\nclf.fit(X, y)\nRandomForestClassifier(...)\nprint(clf.predict([[0, 0, 0, 0]]))\n[1]\n\n'

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.datasets import make_blobs
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.ensemble import ExtraTreesClassifier
# from sklearn.tree import DecisionTreeClassifier

# X, y = make_blobs(n_samples=10000, n_features=10, centers=100, random_state=0)
# pd.DataFrame(X)

# %% [markdown]
# # Forecasting with XG boost

# %%
#setting up dataframe for model
#reorganise columns,remove grade 0, X,y
trainset = pd.read_csv(StringIO(traincsv))
testset = pd.read_csv(StringIO(testcsv))
trainset = trainset[trainset.grade!=0]
trainset = trainset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject', 'grade']]
testset = testset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject']]
y = trainset['grade']
X = trainset.drop('grade',axis='columns').set_index('id')
testset.set_index('id',inplace=True)

# %%
#one hot encoder
X = pd.get_dummies(X)
X
# Out:
#      age  Medu  Fedu  ...  romantic_yes  subject_M  subject_P
# id                    ...
# 0     16     1     1  ...             0          0          1
# 1     18     2     4  ...             0          0          1
# 2     16     4     3  ...             0          0          1
# 3     16     2     1  ...             1          1          0
# 4     20     2     1  ...             1          0          1
# ..   ...   ...   ...  ...           ...        ...        ...
# 726   18     4     3  ...             0          0          1
# 727   15     2     2  ...             1          1          0
# 728   18     1     1  ...             0          1          0
# 729   18     4     4  ...             0          1          0
# 730   17     2     1  ...             0          0          1
#
# [690 rows x 58 columns]

# %%
testset = pd.get_dummies(testset)
testset
# Out:
#      age  Medu  Fedu  ...  romantic_yes  subject_M  subject_P
# id                    ...
# 0     15     3     4  ...             0          1          0
# 1     16     4     3  ...             0          1          0
# 2     15     2     4  ...             0          1          0
# 3     15     3     3  ...             0          1          0
# 4     15     2     3  ...             0          1          0
# ..   ...   ...   ...  ...           ...        ...        ...
# 308   18     4     4  ...             0          0          1
# 309   18     4     4  ...             0          0          1
# 310   18     2     1  ...             1          0          1
# 311   17     2     3  ...             0          0          1
# 312   18     3     2  ...             0          0          1
#
# [313 rows x 58 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.7)  

dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)

param = {'max_depth':4, 'eta':1}
watchlist = [(dtest, 'eval'), (dtrain, 'train')]
num_round = 10

bst = xgb.train(param, dtrain, num_round, watchlist)

preds = bst.predict(dtest)

labels = dtest.get_label()
print('error=%f' % (sum(1 for i in range(len(preds)) if int(preds[i] > 0.5) != labels[i]) / float(len(preds))))
bst.save_model('0001.model')
# Out:
# [0]	eval-rmse:2.75835	train-rmse:2.59459
# [1]	eval-rmse:2.80555	train-rmse:2.22232
# [2]	eval-rmse:2.92925	train-rmse:1.81466
# [3]	eval-rmse:2.95045	train-rmse:1.48208
# [4]	eval-rmse:3.05898	train-rmse:1.26511
# [5]	eval-rmse:3.11037	train-rmse:1.11242
# [6]	eval-rmse:3.1575	train-rmse:0.986619
# [7]	eval-rmse:3.16848	train-rmse:0.916759
# [8]	eval-rmse:3.16567	train-rmse:0.785577
# [9]	eval-rmse:3.1646	train-rmse:0.72236
# error=1.000000

# %%
# dtrain = xgb.DMatrix(X,y)
# testset = xgb.DMatrix(testset)

# param = {'max_depth':4, 'eta':1}
# bst = xgb.train(param, dtrain)
# ypred = bst.predict(testset)
# submission = pd.DataFrame(ypred).reset_index()
# submission.columns = ['id','grade']
# submission.to_csv("submission.csv",index=False)
# files.download('submission.csv')

# %%
# dtrain = xgb.DMatrix(X,y)
# dtest= xgb.DMatrix(testset)

# param = {'max_depth': 7}
# bst = xgb.train(param, dtrain)
# ypred = bst.predict(dtest)
# submission = pd.DataFrame(ypred).reset_index()
# submission.columns = ['id','grade']
# submission.to_csv("submission.csv",index=False)
# files.download('submission.csv')

# %%
# X_train, X_test, y_train, y_test = train_test_split(X, y,train_size=0.4)

# dtrain = xgb.DMatrix(X_train,y_train)
# dtest = xgb.DMatrix(X_test,y_test)

# param = {'max_depth': 7}
# evallist = [(X_test,y_test),(X_train,y_train)]
# num_round = 2
# bst = xgb.train(param, dtrain, num_round,evallist)
# preds = bst.predict(dtest)
# ypred = bst.predict(dtest)

# %% [markdown]
# # Tuning model

# %%
#plan:
#import data
#preapre data: strings, grade, columns, scale
#pick a model: XGboost
#tune model: grid search

# %%
#reading data
trainset = pd.read_csv(StringIO(traincsv))
testset = pd.read_csv(StringIO(testcsv))
#reorder columns
trainset = trainset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject', 'grade']]
testset = testset[['id','school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
       'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
       'Walc', 'health', 'absences', 'subject']]

# %%
#preparing data only on trainset to prevent information leakage
trainset = trainset[trainset['grade']!=0]
#one hot encoder on categorical features
trainset = pd.get_dummies(trainset)
#scale because it isn't more important than other variables

# %%
trainset = trainset.drop('id',axis=1)

# %%
trainset = trainset.reset_index(drop=True)

# %%
from sklearn.preprocessing import StandardScaler
numericColumns = ['age',
              'Medu',
              'Fedu',
              'traveltime',
              'studytime',
              'failures',
              'famrel',
              'freetime',
              'goout',
              'Dalc',
              'Walc',
              'health',
              'absences'
              ]
data = trainset[numericColumns]
scalar = StandardScaler()
new = scalar.fit_transform(data)
df2 = pd.DataFrame(new,columns=numericColumns)
df2
# Out:
#           age      Medu      Fedu  ...      Walc    health  absences
# 0   -0.551266 -1.396666 -1.264833  ...  1.303927  1.040022 -0.768107
# 1    1.050307 -0.507644  1.482495  ... -0.987354 -0.334720  2.172673
# 2   -0.551266  1.270399  0.566719  ... -0.987354  0.352651  0.212153
# 3   -0.551266 -0.507644 -1.264833  ... -0.987354 -1.022091  0.538906
# 4    2.651881 -0.507644 -1.264833  ... -0.223594 -1.022091  0.538906
# ..        ...       ...       ...  ...       ...       ...       ...
# 685  1.050307  1.270399  0.566719  ... -0.987354 -0.334720 -0.441354
# 686 -1.352053 -0.507644 -0.349057  ... -0.987354 -0.334720 -0.768107
# 687  1.050307 -1.396666 -1.264833  ... -0.223594  0.352651 -0.441354
# 688  1.050307  1.270399  1.482495  ... -0.987354 -1.709462 -0.768107
# 689  0.249521 -0.507644 -1.264833  ... -0.987354 -0.334720 -0.768107
#
# [690 rows x 13 columns]

# %%
trainset
# Out:
#      age  Medu  Fedu  ...  romantic_yes  subject_M  subject_P
# 0     16     1     1  ...             0          0          1
# 1     18     2     4  ...             0          0          1
# 2     16     4     3  ...             0          0          1
# 3     16     2     1  ...             1          1          0
# 4     20     2     1  ...             1          0          1
# ..   ...   ...   ...  ...           ...        ...        ...
# 685   18     4     3  ...             0          0          1
# 686   15     2     2  ...             1          1          0
# 687   18     1     1  ...             0          1          0
# 688   18     4     4  ...             0          1          0
# 689   17     2     1  ...             0          0          1
#
# [690 rows x 59 columns]

# %%
for col in numericColumns:
  trainset[col] = df2[col]
trainset
# Out:
#           age      Medu      Fedu  ...  romantic_yes  subject_M  subject_P
# 0   -0.551266 -1.396666 -1.264833  ...             0          0          1
# 1    1.050307 -0.507644  1.482495  ...             0          0          1
# 2   -0.551266  1.270399  0.566719  ...             0          0          1
# 3   -0.551266 -0.507644 -1.264833  ...             1          1          0
# 4    2.651881 -0.507644 -1.264833  ...             1          0          1
# ..        ...       ...       ...  ...           ...        ...        ...
# 685  1.050307  1.270399  0.566719  ...             0          0          1
# 686 -1.352053 -0.507644 -0.349057  ...             1          1          0
# 687  1.050307 -1.396666 -1.264833  ...             0          1          0
# 688  1.050307  1.270399  1.482495  ...             0          1          0
# 689  0.249521 -0.507644 -1.264833  ...             0          0          1
#
# [690 rows x 59 columns]

# %%
trainset.isnull().values.any()
# Out:
# False

# %%
#train model with XGBoost
#partition trainset 70%train 30%validation
X = trainset.drop('grade',axis=1)
y = trainset['grade']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)  
X_train
# Out:
#           age      Medu      Fedu  ...  romantic_yes  subject_M  subject_P
# 420  0.249521 -1.396666 -1.264833  ...             0          1          0
# 675  0.249521 -1.396666  0.566719  ...             0          1          0
# 663  1.050307  0.381377 -1.264833  ...             0          1          0
# 623 -0.551266 -1.396666 -0.349057  ...             0          0          1
# 45  -0.551266 -0.507644 -0.349057  ...             0          1          0
# ..        ...       ...       ...  ...           ...        ...        ...
# 246  1.851094 -2.285688 -1.264833  ...             0          0          1
# 72   0.249521  0.381377 -1.264833  ...             0          1          0
# 606  0.249521  0.381377 -0.349057  ...             0          0          1
# 637  0.249521 -1.396666 -1.264833  ...             0          1          0
# 647 -1.352053  1.270399  0.566719  ...             1          0          1
#
# [482 rows x 58 columns]

# %%
#train model and get a base result
#score to beat during model tuning is 2.66
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)

param = {'max_depth':6, 'eta':0.3,'eval_metric':'rmse','objective':'reg:squarederror','tree_method':'exact'}
watchlist = [(dtest, 'eval'), (dtrain, 'train')]

num_round = 10
bst = xgb.train(param, dtrain, num_round, watchlist)

preds = bst.predict(dtest)

labels = dtest.get_label()
print('error=%f' % (sum(1 for i in range(len(preds)) if int(preds[i] > 0.5) != labels[i]) / float(len(preds))))
# Out:
# [0]	eval-rmse:8.33613	train-rmse:8.44599
# [1]	eval-rmse:6.11098	train-rmse:6.17646
# [2]	eval-rmse:4.67161	train-rmse:4.63239
# [3]	eval-rmse:3.75559	train-rmse:3.56417
# [4]	eval-rmse:3.22465	train-rmse:2.80904
# [5]	eval-rmse:2.93641	train-rmse:2.29777
# [6]	eval-rmse:2.79596	train-rmse:1.91845
# [7]	eval-rmse:2.72165	train-rmse:1.65614
# [8]	eval-rmse:2.68593	train-rmse:1.47008
# [9]	eval-rmse:2.65849	train-rmse:1.32601
# error=1.000000

# %%
#tuning phase
#try determine whether or not there exist insignificant parameter

# %%
#feature importance from  XGboost
#tells me how many times a feature was used relative to others, not very useful
f, ax1 = plt.subplots(1,1,figsize=(10,10))
xgb.plot_importance(bst,ax=ax1)

# %%
#decision tree of model
#not very useful in helping me determine the usefulness of features
f, ax1 = plt.subplots(1,1,figsize=(10,10))
xgb.plot_tree(bst,ax=ax1)

# %%
#use a more accurate way to observe significance
#display result as a horizontal bar chart
f = 'gain'
D = bst.get_score(importance_type= f)

plt.figure(figsize=(10,10))
plt.barh(range(len(D)), list(D.values()), align='center')
plt.yticks(range(len(D)), list(D.keys()),rotation='horizontal')
plt.xlabel('score')
plt.ylabel('feature')
plt.show()

# %%
#observed that age has a very low score
#try re run model without age
#remove weak parameters
#age

# %%
X2 = X.drop('age',axis=1)

X_train, X_test, y_train, y_test = train_test_split(X2, y, train_size=0.7)  
X_train
# Out:
#          Medu      Fedu  traveltime  ...  romantic_yes  subject_M  subject_P
# 9   -0.507644 -0.349057    0.659326  ...             1          0          1
# 623 -1.396666 -0.349057   -0.694647  ...             0          0          1
# 249  1.270399  1.482495   -0.694647  ...             1          0          1
# 488 -0.507644  0.566719   -0.694647  ...             0          1          0
# 223  1.270399  0.566719   -0.694647  ...             0          0          1
# ..        ...       ...         ...  ...           ...        ...        ...
# 668  1.270399  1.482495    0.659326  ...             0          1          0
# 312  1.270399  1.482495   -0.694647  ...             0          0          1
# 8    0.381377 -0.349057    0.659326  ...             0          0          1
# 607 -1.396666 -1.264833    2.013298  ...             0          1          0
# 598 -1.396666 -0.349057   -0.694647  ...             1          1          0
#
# [482 rows x 57 columns]

# %%
#train model without age
#observed that the eval score is worse (2.68 compared to 2.66)
#conclude that age is still a significant feature
dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)

param = {'max_depth':6, 'eta':0.3,'eval_metric':'rmse','objective':'reg:squarederror','tree_method':'exact'}
watchlist = [(dtest, 'eval'), (dtrain, 'train')]

num_round = 10
bst = xgb.train(param, dtrain, num_round, watchlist)

preds = bst.predict(dtest)

labels = dtest.get_label()
print('error=%f' % (sum(1 for i in range(len(preds)) if int(preds[i] > 0.5) != labels[i]) / float(len(preds))))
# Out:
# [0]	eval-rmse:8.3628	train-rmse:8.42502
# [1]	eval-rmse:6.13363	train-rmse:6.17904
# [2]	eval-rmse:4.68984	train-rmse:4.6408
# [3]	eval-rmse:3.81547	train-rmse:3.56307
# [4]	eval-rmse:3.29709	train-rmse:2.83516
# [5]	eval-rmse:3.01831	train-rmse:2.33009
# [6]	eval-rmse:2.83438	train-rmse:1.96132
# [7]	eval-rmse:2.77078	train-rmse:1.70844
# [8]	eval-rmse:2.72631	train-rmse:1.51359
# [9]	eval-rmse:2.67695	train-rmse:1.39606
# error=1.000000

# %%
#try cross validating, a better training method to holdout method
#observe that the optimal number of rounds is 12
#score is only 2.57
X = trainset.drop('grade',axis=1)
y = trainset['grade']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)  

dtrain = xgb.DMatrix(X_train,y_train)
dtest = xgb.DMatrix(X_test,y_test)
num_boost_round = 999

params = {'max_depth':6, 'eta':0.3,'eval_metric':'rmse','objective':'reg:squarederror','tree_method':'exact'}

cv_results = xgb.cv(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    seed=0,
    nfold=5,
    metrics={'rmse'},
    early_stopping_rounds=10
)
cv_results
# Out:
#     train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0          8.542533        0.021868        8.551630       0.166923
# 1          6.244214        0.020792        6.303320       0.182764
# 2          4.669678        0.016277        4.818539       0.179377
# 3          3.569572        0.022479        3.879237       0.212679
# 4          2.801337        0.029200        3.299961       0.200242
# 5          2.275122        0.028852        2.948968       0.220902
# 6          1.895744        0.027323        2.740709       0.220556
# 7          1.633047        0.018093        2.645610       0.199884
# 8          1.419877        0.025803        2.592230       0.209626
# 9          1.279675        0.025924        2.577693       0.209710
# 10         1.168576        0.035247        2.578188       0.219217
# 11         1.078195        0.033606        2.569218       0.218063
# 12         0.995151        0.027186        2.565815       0.214772

# %%
cv_results['test-rmse-mean'].min()
# Out:
# 2.5658149999999997

# %%
#brute force approach to find optimal numbers
#observe that the best params for this model is max_depth = 3 and min_child_weight = 3, RMSE: 2.4479124
#source of code from
#https://blog.cambridgespark.com/hyperparameter-tuning-in-xgboost-4ff9100a3b2f
gridsearch_params = [
    (max_depth, min_child_weight)
    for max_depth in range(1,10)
    for min_child_weight in range(1,10)
]

# Define initial best params and MAE
min_rmse = 2.56
best_params = None
for max_depth, min_child_weight in gridsearch_params:
    print("CV with max_depth={}, min_child_weight={}".format(
                             max_depth,
                             min_child_weight))
    # Update our parameters
    params['max_depth'] = max_depth
    params['min_child_weight'] = min_child_weight
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=0,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=10
    )
    # Update best rmse
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tRMSE {} for {} rounds".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = (max_depth,min_child_weight)
print("Best params: {}, {}, RMSE: {}".format(best_params[0], best_params[1], min_rmse))
# Out:
# CV with max_depth=1, min_child_weight=1
# 	RMSE 2.4700776 for 36 rounds
# CV with max_depth=1, min_child_weight=2
# 	RMSE 2.4621268 for 55 rounds
# CV with max_depth=1, min_child_weight=3
# 	RMSE 2.4638663999999997 for 55 rounds
# CV with max_depth=1, min_child_weight=4
# 	RMSE 2.4641208 for 55 rounds
# CV with max_depth=1, min_child_weight=5
# 	RMSE 2.4641208 for 55 rounds
# CV with max_depth=1, min_child_weight=6
# 	RMSE 2.4521977999999995 for 76 rounds
# CV with max_depth=1, min_child_weight=7
# 	RMSE 2.4594008 for 46 rounds
# CV with max_depth=1, min_child_weight=8
# 	RMSE 2.460118 for 50 rounds
# CV with max_depth=1, min_child_weight=9
# 	RMSE 2.460118 for 50 rounds
# CV with max_depth=2, min_child_weight=1
# 	RMSE 2.5010687999999996 for 22 rounds
# CV with max_depth=2, min_child_weight=2
# 	RMSE 2.4784821999999997 for 28 rounds
# CV with max_depth=2, min_child_weight=3
# 	RMSE 2.5003995999999997 for 24 rounds
# CV with max_depth=2, min_child_weight=4
# ...

# %%
# next optimise the Parameters subsample and colsample_bytree using gridsearch again
#observe that the best subsample and colsample are both 0.9 with the rmse score of 2.4393546

gridsearch_params = [
    (subsample, colsample)
    for subsample in [i/10. for i in range(7,11)]
    for colsample in [i/10. for i in range(7,11)]
]

min_mae = 2.44
best_params = None
# We start by the largest values and go down to the smallest
for subsample, colsample in reversed(gridsearch_params):
    print("CV with subsample={}, colsample={}".format(
                             subsample,
                             colsample))
    # We update our parameters
    params['subsample'] = subsample
    params['colsample_bytree'] = colsample
    # Run CV
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=num_boost_round,
        seed=42,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=10
    )
    # Update best score
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tRMSE {} for {} rounds".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = (subsample,colsample)
    if best_params is None:
      best_params = (0,0)
      print('no best parameter')
print("Best params: {}, {}, RMSE: {}".format(best_params[0], best_params[1], min_rmse))
# Out:
# CV with subsample=1.0, colsample=1.0
# 	RMSE 2.5923977999999996 for 11 rounds
# no best parameter
# CV with subsample=1.0, colsample=0.9
# 	RMSE 2.5159811999999997 for 13 rounds
# CV with subsample=1.0, colsample=0.8
# 	RMSE 2.5497844 for 11 rounds
# CV with subsample=1.0, colsample=0.7
# 	RMSE 2.5406694 for 11 rounds
# CV with subsample=0.9, colsample=1.0
# 	RMSE 2.5408664 for 12 rounds
# CV with subsample=0.9, colsample=0.9
# 	RMSE 2.5458474000000004 for 11 rounds
# CV with subsample=0.9, colsample=0.8
# 	RMSE 2.4923587999999994 for 11 rounds
# CV with subsample=0.9, colsample=0.7
# 	RMSE 2.5361368 for 11 rounds
# CV with subsample=0.8, colsample=1.0
# 	RMSE 2.5284808 for 11 rounds
# CV with subsample=0.8, colsample=0.9
# 	RMSE 2.5689096 for 10 rounds
# CV with subsample=0.8, colsample=0.8
# 	RMSE 2.5039483999999996 for 11 rounds
# CV with subsample=0.8, colsample=0.7
# 	RMSE 2.5038197999999996 for 12 rounds
# CV with subsample=0.7, colsample=1.0
# 	RMSE 2.4954248 for 12 rounds
# ...

# %%
params['subsample'] = 0.9
params['colsample_bytree'] = 0.9
params['max_depth'] = 3
params['min_child_weight'] = 3

# %%
#next optimise eta
#observed that the best eta = 0.3 with a RMSEs score of 2.5244666

# %time
min_rmse = 5
best_params = None

for eta in [1,0.9,0.8,0.7,0.6,0.5,0.4,0.3,0.2,0.1,0.05,.3, .2, .1, .05, .01, .005]:
    print("CV with eta={}".format(eta))
    # We update our parameters
    params['eta'] = eta
    # Run and time CV
    cv_results = xgb.cv(
            params,
            dtrain,
            num_boost_round=num_boost_round,
            seed=0,
            nfold=5,
            metrics=['rmse'],
            early_stopping_rounds=10
          )
    # Update best score
    mean_mae = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print("\tRMSE {} for {} rounds\n".format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_params = eta
print("Best params: {}, RMSE: {}".format(best_params, min_rmse))
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.25 µs
# CV with eta=1
# 	RMSE 2.4862058 for 1 rounds
#
# CV with eta=0.9
# 	RMSE 2.4862058 for 1 rounds
#
# CV with eta=0.8
# 	RMSE 2.4862058 for 4 rounds
#
# CV with eta=0.7
# 	RMSE 2.4862058 for 5 rounds
#
# CV with eta=0.6
# 	RMSE 2.4862058 for 9 rounds
#
# CV with eta=0.5
# 	RMSE 2.4862058 for 12 rounds
#
# CV with eta=0.4
# 	RMSE 2.4862058 for 8 rounds
#
# CV with eta=0.3
# 	RMSE 2.4862058 for 17 rounds
#
# CV with eta=0.2
# 	RMSE 2.4862058 for 33 rounds
#
# CV with eta=0.1
# 	RMSE 2.4862058 for 51 rounds
#
# CV with eta=0.05
# 	RMSE 2.4862058 for 123 rounds
#
# CV with eta=0.3
# 	RMSE 2.4862058 for 17 rounds
#
# CV with eta=0.2
# 	RMSE 2.4862058 for 33 rounds
#
# CV with eta=0.1
# 	RMSE 2.4862058 for 51 rounds
#
# CV with eta=0.05
# 	RMSE 2.4862058 for 123 rounds
#
# CV with eta=0.01
# 	RMSE 2.4862058 for 535 rounds
#
# CV with eta=0.005
# 	RMSE 2.4862058 for 998 rounds
#
# Best params: 1, RMSE: 2.4862058

# %%
params['eta'] = 1

# %%
params
# Out:
# {'colsample_bytree': 0.9,
#  'eta': 1,
#  'eval_metric': 'rmse',
#  'max_depth': 3,
#  'min_child_weight': 3,
#  'objective': 'reg:squarederror',
#  'subsample': 0.9,
#  'tree_method': 'exact'}

# %%
num_boost_round = model.best_iteration + 1
best_model = xgb.train(
    params,
    dtrain,
    num_boost_round=num_boost_round,
    evals=[(dtest, "Test")]
)
best_model.save_model("my_model.model")
# Out:
# [0]	Test-rmse:2.54565
# [1]	Test-rmse:2.55562
# [2]	Test-rmse:2.71775
# [3]	Test-rmse:2.84197
# [4]	Test-rmse:2.85279
# [5]	Test-rmse:2.94009
# [6]	Test-rmse:2.98147
# [7]	Test-rmse:2.95896
# [8]	Test-rmse:2.96364
# [9]	Test-rmse:3.02025
# [10]	Test-rmse:2.98504
# [11]	Test-rmse:2.9488
# [12]	Test-rmse:2.96071
# [13]	Test-rmse:2.96069
# [14]	Test-rmse:2.95293
# [15]	Test-rmse:3.02353
# [16]	Test-rmse:3.01022
# [17]	Test-rmse:3.02808
# [18]	Test-rmse:3.01839
# [19]	Test-rmse:3.01188

# %%
#getting ready to make prediction
#first make testset look like trainset except we keep it unscaled to preserve dinosaurs

# %%
X.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'school_GP',
#        'school_MS', 'sex_F', 'sex_M', 'address_R', 'address_U', 'famsize_GT3',
#        'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Mjob_at_home', 'Mjob_health',
#        'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home',
#        'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher',
#        'reason_course', 'reason_home', 'reason_other', 'reason_reputation',
#        'guardian_father', 'guardian_mother', 'guardian_other', 'schoolsup_no',
#        'schoolsup_yes', 'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes',
#        'activities_no', 'activities_yes', 'nursery_no', 'nursery_yes',
#        'higher_no', 'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
#        'romantic_yes', 'subject_M', 'subject_P'],
#       dtype='object')

# %%
#one hot encoder on categorical features of testset
testset = pd.get_dummies(testset)
testset = testset.set_index('id')
testset
# Out:
#      age  Medu  Fedu  ...  romantic_yes  subject_M  subject_P
# id                    ...
# 0     15     3     4  ...             0          1          0
# 1     16     4     3  ...             0          1          0
# 2     15     2     4  ...             0          1          0
# 3     15     3     3  ...             0          1          0
# 4     15     2     3  ...             0          1          0
# ..   ...   ...   ...  ...           ...        ...        ...
# 308   18     4     4  ...             0          0          1
# 309   18     4     4  ...             0          0          1
# 310   18     2     1  ...             1          0          1
# 311   17     2     3  ...             0          0          1
# 312   18     3     2  ...             0          0          1
#
# [313 rows x 58 columns]

# %%
testset.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'school_GP',
#        'school_MS', 'sex_F', 'sex_M', 'address_R', 'address_U', 'famsize_GT3',
#        'famsize_LE3', 'Pstatus_A', 'Pstatus_T', 'Mjob_at_home', 'Mjob_health',
#        'Mjob_other', 'Mjob_services', 'Mjob_teacher', 'Fjob_at_home',
#        'Fjob_health', 'Fjob_other', 'Fjob_services', 'Fjob_teacher',
#        'reason_course', 'reason_home', 'reason_other', 'reason_reputation',
#        'guardian_father', 'guardian_mother', 'guardian_other', 'schoolsup_no',
#        'schoolsup_yes', 'famsup_no', 'famsup_yes', 'paid_no', 'paid_yes',
#        'activities_no', 'activities_yes', 'nursery_no', 'nursery_yes',
#        'higher_no', 'higher_yes', 'internet_no', 'internet_yes', 'romantic_no',
#        'romantic_yes', 'subject_M', 'subject_P'],
#       dtype='object')

# %%
dtest= xgb.DMatrix(testset)
ypred = best_model.predict(dtest)

# %%
ypred.size
# Out:
# 313

# %%
#checking model with the validtion set
#the values are normal looking 
dtest2 = xgb.DMatrix(X_test,y_test)
ypred2 = best_model.predict(dtest2) 
ypred2
# Out:
# array([13.067709 , 13.616475 , 16.730202 ,  9.494686 ,  8.229591 ,
#         8.648009 ,  7.668436 ,  9.69423  , 12.071836 , 10.41923  ,
#        14.199711 ,  8.378914 ,  7.5831556, 10.719437 ,  8.72106  ,
#        14.452289 , 10.980911 , 11.357397 , 18.045816 ,  7.3123317,
#        11.534065 , 14.137431 ,  7.626463 , 13.784559 , 11.434454 ,
#        12.083924 , 14.735494 , 15.202958 ,  8.709371 , 12.44935  ,
#         9.5527725, 14.253675 , 15.173494 , 15.316623 , 12.104099 ,
#        13.883456 , 12.247062 , 10.829449 , 12.814203 , 10.54616  ,
#        13.139578 , 11.151941 , 12.424269 , 10.373096 , 11.467411 ,
#        13.022027 ,  8.460764 , 14.816588 , 13.291263 , 11.053712 ,
#        10.703209 , 11.109235 , 12.260255 , 12.712168 , 12.109453 ,
#        14.540464 ,  8.8350525, 11.482147 , 12.7400255, 12.178301 ,
#        11.373129 ,  8.924207 , 13.255311 ,  5.520631 , 10.24195  ,
#         9.72531  , 13.167143 ,  9.6126   , 10.928899 , 11.925297 ,
# ...

# %%
#terrible score for testset
# and there are negative numbers??!?!?
# lost...

# %%
for x in ypred:
  if x<0:
    print(x)
# Out:
# -1.0860943
# -1.9735346
# -0.5006921

# %%
ypred = np.round(ypred)
ypred = np.absolute(ypred)

# %%
plt.figure()
plt.hist(ypred,bins=20)
plt.title('histogram of predicted testset marks')
# Out:
# Text(0.5, 1.0, 'histogram of predicted testset marks')

# %%
plt.figure()
plt.hist(ypred2,bins=20)
plt.title('histogram of predicted vaildation set marks')
# Out:
# Text(0.5, 1.0, 'histogram of predicted vaildation set marks')

# %%
plt.figure()
plt.hist(y,bins=20)
plt.title('histogram of train set marks')
# Out:
# Text(0.5, 1.0, 'histogram of train set marks')

# %%
submission = pd.DataFrame(ypred).reset_index()
submission.columns = ['id','grade']
submission.to_csv("submission.csv",index=False)
# files.download('submission.csv')
